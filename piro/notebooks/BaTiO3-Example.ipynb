# %% [markdown]
# ## Synthesis planning for BaTiO3

# %% [markdown]
# This notebook typically takes around 5 minutes to complete.

# %%
import pandas as pd
from piro.route import SynthesisRoutes
pd.set_option('display.width', 700)
pd.set_option('display.max_colwidth', 300)
# Out:
# /Users/josephmontoya/PycharmProjects/trina_tutorial/piro/piro/utils.py:15: FutureWarning: The substrate_analyzer module is being moved to the interfaces submodule in analysis. These imports will break in Pymatgen 2023
#   from pymatgen.analysis.substrate_analyzer import SubstrateAnalyzer

# %% [markdown]
# We will specify the mp-id of our target phase, alongside a few phases we want explicitly included as part of precursor library, as they are not groundstate structures (to which we are limiting our general search to).

# %%
mp_id = 'mp-5986'       # Target compound
BaTi2O5 = 'mp-3943'     # Additional relevant phase to explicitly include
TiO_ordered = 'mp-1203' # Additional relevant phase to explicitly include
TiO2_rutile = 'mp-2657' # Additional relevant phase to explicitly include
BaCO3_beta = 'mp-4559'  # Additional relevant phase to explicitly include

# %%
router = SynthesisRoutes(
    mp_id, 
    confine_to_icsd=True, 
    confine_to_stables=True, 
    explicit_includes=[TiO2_rutile,BaCO3_beta,TiO_ordered,BaTi2O5], 
    exclude_compositions=['BaTiO3'],
    allow_gas_release=True,
    confine_competing_to_icsd=False,
    add_elements=['C']
)
# Out:
# /Users/josephmontoya/miniconda3/envs/tutorial/lib/python3.9/site-packages/mp_api/client/mprester.py:148: UserWarning: mpcontribs-client not installed. Install the package to query MPContribs data, or construct pourbaix diagrams: 'pip install mpcontribs-client'
#   warnings.warn(
# Retrieving ThermoDoc documents:   0%|          | 0/3 [00:00<?, ?it/s]
# /Users/josephmontoya/miniconda3/envs/tutorial/lib/python3.9/site-packages/mp_api/client/mprester.py:499: UserWarning: The 'inc_structure' argument is deprecated as structure data is now always included in all returned entry objects.
#   warnings.warn(
# Retrieving ThermoDoc documents:   0%|          | 0/364 [00:00<?, ?it/s]
# Retrieving ProvenanceDoc documents:   0%|          | 0/364 [00:00<?, ?it/s]
# Total # of entries found in this chemistry:  364
# explicitly including:  ['mp-2657', 'mp-4559', 'mp-1203', 'mp-3943']
# Total # of precursors materials obeying the provided filters:  28
# Precursor library ready.
# Epitaxy and Similarity cache type:  CacheType.FILE_CACHE
# Epitaxies ready
# similarity matrix ready

# %%
f = router.recommend_routes(
    temperature=1400,        
    show_known_precursors_only=False,
    max_component_precursors=2, 
    display_peroxides=False,
    custom_text=' - 1400K, air, standard reactants [expanded view]',
    w=640,h=480, 
    show_fraction_known_precursors=False,
    add_pareto=True, 
    yrange=(-0.1,0.9)
)
# Out:
# balancing reactions:   0%|          | 0/20475.0 [00:00<?, ?it/s]
# Calculating reaction results: 100%|███████████████████| 2326/2326 [00:01<00:00, 1235.25it/s]

# %%
f.show()

# %% [markdown]
# Let's include peroxides in our precursor library:

# %%
f2 = router.recommend_routes(
    temperature=1400, 
    show_known_precursors_only=False,
    max_component_precursors=2, 
    display_peroxides=True,
    custom_text=' - 1400K, air, standard reactants and peroxides',
    w=640,h=480,
    show_fraction_known_precursors=False,
    add_pareto=True, 
    yrange=(-0.1,0.9)
)
f2.show()
# Out:
# <div>                            <div id="1abb5d52-0448-4d87-ae65-529f0fb6e1a1" class="plotly-graph-div" style="height:480px; width:640px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1abb5d52-0448-4d87-ae65-529f0fb6e1a1")) {                    Plotly.newPlot(                        "1abb5d52-0448-4d87-ae65-529f0fb6e1a1",                        [{"customdata":[["1.0 BaO(mp-1342) + 1.0 TiO2(mp-554278)"],["1.0 BaO(mp-1342) + 1.0 TiO2(mp-2657)"],["0.7 Ba(mp-122) + 0.3 BaO10(mp-1182576) + 1.0 Ti(mp-72)"],["0.75 Ba(mp-122) + 0.25 BaO10(mp-1182576) + 0.5 Ti2O(mp-1215)"],["0.85 Ba(mp-122) + 0.15 BaO10(mp-1182576) + 0.5 Ti2O3(mp-458)"],["0.7333 Ba(mp-122) + 0.2667 BaO10(mp-1182576) + 0.3333 Ti3O(mp-2591)"],["0.8667 Ba(mp-122) + 0.1333 BaO10(mp-1182576) + 0.3333 Ti3O5(mp-1147)"],["0.7167 Ba(mp-122) + 0.2833 BaO10(mp-1182576) + 0.1667 Ti6O(mp-554098)"],["0.8 Ba(mp-122) + 0.2 BaO10(mp-1182576) + 1.0 TiO(mp-1071163)"],["0.8 Ba(mp-122) + 0.2 BaO10(mp-1182576) + 1.0 TiO(mp-1203)"],["0.9 Ba(mp-122) + 0.1 BaO10(mp-1182576) + 1.0 TiO2(mp-554278)"],["0.9 Ba(mp-122) + 0.1 BaO10(mp-1182576) + 1.0 TiO2(mp-2657)"],["0.25 Ba(mp-122) + 0.75 BaO2(mp-1105) + 0.5 Ti2O3(mp-458)"],["0.3333 Ba(mp-122) + 0.6667 BaO2(mp-1105) + 0.3333 Ti3O5(mp-1147)"],["1.0 BaO2(mp-1105) + 1.0 TiO(mp-1071163)"],["1.0 BaO2(mp-1105) + 1.0 TiO(mp-1203)"],["0.5 Ba(mp-122) + 0.5 BaO2(mp-1105) + 1.0 TiO2(mp-554278)"],["0.5 Ba(mp-122) + 0.5 BaO2(mp-1105) + 1.0 TiO2(mp-2657)"],["1.0 BaCO3(mp-5504) + -1.0 CO2(mp-20066) + 1.0 TiO2(mp-554278)"],["1.0 BaCO3(mp-5504) + -1.0 CO2(mp-20066) + 1.0 TiO2(mp-2657)"],["1.0 Ba(mp-122) + 1.5 O2(mp-723285) + 1.0 Ti(mp-72)"],["1.0 Ba(mp-122) + 1.25 O2(mp-723285) + 0.5 Ti2O(mp-1215)"],["1.0 Ba(mp-122) + 0.75 O2(mp-723285) + 0.5 Ti2O3(mp-458)"],["1.0 Ba(mp-122) + 1.3333 O2(mp-723285) + 0.3333 Ti3O(mp-2591)"],["1.0 Ba(mp-122) + 0.6667 O2(mp-723285) + 0.3333 Ti3O5(mp-1147)"],["1.0 Ba(mp-122) + 1.4167 O2(mp-723285) + 0.1667 Ti6O(mp-554098)"],["1.0 Ba(mp-122) + 1.0 O2(mp-723285) + 1.0 TiO(mp-1071163)"],["1.0 Ba(mp-122) + 1.0 O2(mp-723285) + 1.0 TiO(mp-1203)"],["1.0 Ba(mp-122) + 0.5 O2(mp-723285) + 1.0 TiO2(mp-554278)"],["1.0 Ba(mp-122) + 0.5 O2(mp-723285) + 1.0 TiO2(mp-2657)"],["1.0 BaCO3(mp-4559) + -1.0 CO2(mp-20066) + 1.0 TiO2(mp-554278)"],["1.0 BaCO3(mp-4559) + -1.0 CO2(mp-20066) + 1.0 TiO2(mp-2657)"],["0.6 Ba(mp-122) + 0.4 BaO10(mp-1182576) + -0.5 CO2(mp-20066) + 0.5 Ti2C(mp-10721)"],["0.575 Ba(mp-122) + 0.425 BaO10(mp-1182576) + -0.625 CO2(mp-20066) + 0.125 Ti8C5(mp-27919)"],["0.5 Ba(mp-122) + 0.5 BaO10(mp-1182576) + -1.0 CO2(mp-20066) + 1.0 TiC(mp-631)"],["1.0 Ba(mp-122) + -0.5 CO2(mp-20066) + 2.0 O2(mp-723285) + 0.5 Ti2C(mp-10721)"],["1.0 Ba(mp-122) + -0.625 CO2(mp-20066) + 2.125 O2(mp-723285) + 0.125 Ti8C5(mp-27919)"],["1.0 Ba(mp-122) + -1.0 CO2(mp-20066) + 2.5 O2(mp-723285) + 1.0 TiC(mp-631)"],["0.7778 BaO(mp-1342) + 0.2222 BaO10(mp-1182576) + 1.0 Ti(mp-72)"],["0.8333 BaO(mp-1342) + 0.1667 BaO10(mp-1182576) + 0.5 Ti2O(mp-1215)"],["0.9444 BaO(mp-1342) + 0.0556 BaO10(mp-1182576) + 0.5 Ti2O3(mp-458)"],["0.5 BaO(mp-1342) + 0.5 BaO2(mp-1105) + 0.5 Ti2O3(mp-458)"],["1.0 BaO(mp-1342) + 0.25 O2(mp-723285) + 0.5 Ti2O3(mp-458)"],["0.125 BaO10(mp-1182576) + 0.875 BaO2(mp-1105) + 1.0 Ti(mp-72)"],["0.0833 BaO10(mp-1182576) + 0.9167 BaO2(mp-1105) + 0.3333 Ti3O(mp-2591)"],["0.1042 BaO10(mp-1182576) + 0.8958 BaO2(mp-1105) + 0.1667 Ti6O(mp-554098)"],["0.7778 BaCO3(mp-5504) + 0.2222 BaO10(mp-1182576) + -0.7778 CO2(mp-20066) + 1.0 Ti(mp-72)"],["0.6667 BaCO3(mp-5504) + 0.3333 BaO10(mp-1182576) + -1.1667 CO2(mp-20066) + 0.5 Ti2C(mp-10721)"],["0.8333 BaCO3(mp-5504) + 0.1667 BaO10(mp-1182576) + -0.8333 CO2(mp-20066) + 0.5 Ti2O(mp-1215)"],["0.9444 BaCO3(mp-5504) + 0.0556 BaO10(mp-1182576) + -0.9444 CO2(mp-20066) + 0.5 Ti2O3(mp-458)"],["0.8148 BaCO3(mp-5504) + 0.1852 BaO10(mp-1182576) + -0. ...

# %% [markdown]
# We can also rank reactions:

# %%
router.topsis().head(10)
# Out:
#                                  n_competing   barrier                                                                          summary    energy  enthalpy exp_precursors         precursor_formulas  topsis_score
# mp-1105_mp-1203                            8  0.112723                                             1.0 BaO2(mp-1105) + 1.0 TiO(mp-1203) -1.040828 -1.040828            1.0                [BaO2, TiO]      0.998780
# mp-1071163_mp-1105                         8  0.113151                                          1.0 BaO2(mp-1105) + 1.0 TiO(mp-1071163) -1.023732 -1.023732            1.0                [BaO2, TiO]      0.998738
# mp-1105_mp-1215_mp-458                    19  0.112366                      1.0 BaO2(mp-1105) + 0.25 Ti2O(mp-1215) + 0.25 Ti2O3(mp-458) -1.055720 -1.055720         0.6667        [BaO2, Ti2O, Ti2O3]      0.965329
# mp-1105_mp-20066_mp-4559_mp-458           19  0.119079  0.5 BaCO3(mp-4559) + 0.5 BaO2(mp-1105) + -0.5 CO2(mp-20066) + 0.5 Ti2O3(mp-458) -0.849940 -0.337249            1.0  [BaCO3, BaO2, CO2, Ti2O3]      0.965281
# mp-1105_mp-20066_mp-458_mp-5504           19  0.119579  0.5 BaCO3(mp-5504) + 0.5 BaO2(mp-1105) + -0.5 CO2(mp-20066) + 0.5 Ti2O3(mp-458) -0.839017 -0.326326            1.0  [BaCO3, BaO2, CO2, Ti2O3]      0.965277
# mp-1105_mp-1342_mp-458                    20  0.107559                         0.5 BaO(mp-1342) + 0.5 BaO2(mp-1105) + 0.5 Ti2O3(mp-458) -0.621523 -0.621523            1.0         [BaO, BaO2, Ti2O3]      0.962315
# mp-1105_mp-2591_mp-458                    21  0.112182                  1.0 BaO2(mp-1105) + 0.2857 Ti2O3(mp-458) + 0.1429 Ti3O(mp-2591) -1.063655 -1.063655         0.6667        [BaO2, Ti2O3, Ti3O]      0.959264
# mp-1105_mp-458_mp-554098                  22  0.111940                1.0 BaO2(mp-1105) + 0.3125 Ti2O3(mp-458) + 0.0625 Ti6O(mp-554098) -1.074378 -1.074378         0.6667        [BaO2, Ti2O3, Ti6O]      0.956259
# mp-1105_mp-122_mp-458                     23  0.118604                         0.25 Ba(mp-122) + 0.75 BaO2(mp-1105) + 0.5 Ti2O3(mp-458) -0.860723 -0.860723            1.0          [Ba, BaO2, Ti2O3]      0.953222
# mp-1105_mp-458_mp-72                      24  0.111117                      1.0 BaO2(mp-1105) + 0.3333 Ti(mp-72) + 0.3333 Ti2O3(mp-458) -1.085767 -1.085767            1.0          [BaO2, Ti, Ti2O3]      0.950302
