# %%
mp_id = 'mp-685194'

# %%
from rxn.route import SynthesisRoutes

# %%
router = SynthesisRoutes(mp_id, add_element='C')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:  1.3min finished
# Epitaxies ready
# Similarity matrix ready
# Precursor library ready.

# %%
router.recommend_routes(t=1500, p=0.00001, allow_gas_release=True)
# Out:
# <div>
#
#
#             <div id="404eb6ec-d56d-4cd0-ac6c-d761a3513e7f" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("404eb6ec-d56d-4cd0-ac6c-d761a3513e7f")) {
#                     Plotly.newPlot(
#                         '404eb6ec-d56d-4cd0-ac6c-d761a3513e7f',
#                         [{"customdata": [["2.0 Li2O(mp-1960) + 5.0 TiO2(mp-554278)"], ["2.5 LiTi2O4(mp-5670) + 0.75 Li2O(mp-1960) + 0.625 O2(mp-12957)"], ["1.0 LiTi2O4(mp-5670) + 3.0 LiTiO2(mp-38280) + 1.0 O2(mp-12957)"], ["2.0 LiTi2O4(mp-5670) + 1.0 TiO2(mp-554278) + 1.0 Li2O2(mp-841)"], ["4.0 TiO2(mp-554278) + 1.0 Li4TiO4(mp-9172)"], ["3.0 TiO2(mp-554278) + 2.0 Li2TiO3(mp-2931)"], ["2.5 LiTi2O4(mp-5670) + 1.5 Li(mp-135) + 1.0 O2(mp-12957)"], ["1.0 LiTi2O4(mp-5670) + 1.0 Ti3O5(mp-1147) + 1.5 Li2O2(mp-841)"], ["2.5 LiTi2O4(mp-5670) + 1.5 LiC12(mp-1021323) + -18.0 CO2(mp-20066) + 19.0 O2(mp-12957)"], ["2.5 LiTi2O4(mp-5670) + 0.75 Li2O2(mp-841) + 0.25 O2(mp-12957)"], ["2.2857 LiTi2O4(mp-5670) + 0.4286 Li4TiO4(mp-9172) + 0.5714 O2(mp-12957)"], ["2.0 LiTi2O4(mp-5670) + 1.0 Li2TiO3(mp-2931) + 0.5 O2(mp-12957)"], ["2.0 Li2CO3(mp-3054) + 5.0 TiO2(mp-554278) + -2.0 CO2(mp-20066)"], ["2.5 LiTi2O4(mp-5670) + 0.75 Li2CO3(mp-3054) + -0.75 CO2(mp-20066) + 0.625 O2(mp-12957)"], ["4.0 LiC12(mp-1021323) + 0.625 Ti8C5(mp-27919) + -51.125 CO2(mp-20066) + 57.125 O2(mp-12957)"], ["2.0 Li2O(mp-1960) + 2.5 Ti2O(mp-1215) + 3.75 O2(mp-12957)"], ["2.0 Li2O(mp-1960) + 0.8333 Ti6O(mp-554098) + 4.5833 O2(mp-12957)"], ["2.0 Li2O(mp-1960) + 1.6667 Ti3O(mp-2591) + 4.1667 O2(mp-12957)"], ["0.3333 Li2O(mp-1960) + 1.6667 Ti3O5(mp-1147) + 1.6667 Li2O2(mp-841)"], ["2.0 Li2O(mp-1960) + 1.6667 Ti3O5(mp-1147) + 0.8333 O2(mp-12957)"], ["2.0 Li2O(mp-1960) + 5.0 Ti(mp-72) + 5.0 O2(mp-12957)"], ["2.0 Li2O(mp-1960) + 5.0 TiO(mp-1071163) + 2.5 O2(mp-12957)"], ["2.0 Li2O(mp-1960) + 2.5 Ti2O3(mp-458) + 1.25 O2(mp-12957)"], ["0.5 Ti2O(mp-1215) + 4.0 LiTiO2(mp-38280) + 1.75 O2(mp-12957)"], ["0.6667 Ti2O(mp-1215) + 3.6667 TiO2(mp-554278) + 2.0 Li2O2(mp-841)"], ["2.5 Ti2O(mp-1215) + 4.0 Li(mp-135) + 4.75 O2(mp-12957)"], ["0.1429 Ti2O(mp-1215) + 1.5714 Ti3O5(mp-1147) + 2.0 Li2O2(mp-841)"], ["4.0 LiC12(mp-1021323) + 2.5 Ti2O(mp-1215) + -48.0 CO2(mp-20066) + 52.75 O2(mp-12957)"], ["2.5 Ti2O(mp-1215) + 2.0 Li2O2(mp-841) + 2.75 O2(mp-12957)"], ["2.0 Ti2O(mp-1215) + 1.0 Li4TiO4(mp-9172) + 3.0 O2(mp-12957)"], ["1.5 Ti2O(mp-1215) + 2.0 Li2TiO3(mp-2931) + 2.25 O2(mp-12957)"], ["2.0 LiTiO2(mp-38280) + 3.0 TiO2(mp-554278) + 1.0 Li2O2(mp-841)"], ["4.0 LiTiO2(mp-38280) + 1.0 TiO2(mp-554278) + 1.0 O2(mp-12957)"], ["4.0 LiTiO2(mp-38280) + 0.1667 Ti6O(mp-554098) + 1.9167 O2(mp-12957)"], ["4.0 LiTiO2(mp-38280) + 0.3333 Ti3O(mp-2591) + 1.8333 O2(mp-12957)"], ["0.5 LiTiO2(mp-38280) + 1.5 Ti3O5(mp-1147) + 1.75 Li2O2(mp-841)"], ["4.0 LiTiO2(mp-38280) + 0.3333 Ti3O5(mp-1147) + 1.1667 O2(mp-12957)"], ["4.0 LiTiO2(mp-38280) + 1.0 Ti(mp-72) + 2.0 O2(mp-12957)"], ["4.0 LiTiO2(mp-38280) + 1.0 TiO(mp-1071163) + 1.5 O2(mp-12957)"], ["4.0 LiTiO2(mp-38280) + 0.5 Ti2O3(mp-458) + 1.25 O2(mp-12957)"], ["3.9091 TiO2(mp-554278) + 0.1818 Ti6O(mp-554098) + 2.0 Li2O2(mp-841)"], ["3.8 TiO2(mp-554278) + 0.4 Ti3O(mp-2591) + 2.0 Li2O2(mp-841)"], ["5.0 TiO2(mp-554278) + 2.0 Li(mp-135) + 1.0 Li2O2(mp-841)"], ["5.0 TiO2(mp-554278) + 4.0 Li(mp-135) + 1.0 O2(mp-12957)"], ["4.0 TiO2(mp-554278) + 1.0 Ti(mp-72) + 2.0 Li2O2(mp-841)"], ["0.08 LiC12(mp-1021323) + 5.0 TiO2(mp-554278) + -0.96 CO2(mp-20066) + 1.96 Li2O2(mp-841)"], ["4.0 LiC12(mp-1021323) + 5.0 TiO2(mp-554278) + -48.0 CO2(mp-20066) + 49.0 O2(mp-12957)"], ["3.0 TiO2(mp-554278) + 2.0 Li2O2(mp-841) + 2.0 TiO(mp-1071163)"], ["1.0 TiO2(mp-554278) + 2.0 Li2O2(mp-841) + 2.0 Ti2O3(mp-458)"], ["5.0 TiO2(mp-554278) + 2.0 Li2O2(mp-841) + -1.0 O2(mp-12957)"], ["0.8333 Ti6O(mp-554098) + 4.0 Li(mp-135) + 5.5833 O2(mp-12957)"], ["0.037 Ti6O(mp-554098) + 1.5926 Ti3O5(mp-1147) + 2.0 Li2O2(mp-841)"], ["4.0 LiC12(mp-1021323) + 0.8333 Ti6O(mp-554098) + -48.0 CO2(mp-20066) + 53.5833 O2(mp-12957)"], ["0.8333 Ti6O(mp-554098) + 2.0 Li2O2(mp-841) + 3.5833 O2(mp-12957)"], ["0.6667 Ti6O(mp-554098) + 1.0 Li4TiO4(mp-9172) + 3.6667 O2(mp-12957)"], ["0.5 Ti6O(mp-554098) + 2.0 Li2TiO3(mp-2931) + 2.75 O2(mp-12957)"], ["1.6667 Ti3O(mp-2591) + 4.0 Li(mp-135) + 5.1667 O2(mp-12957)"], ["0.0833 Ti3O(mp-2 ...

# %%
import numpy as np

# %%
sorted([(router.reactions[i]['barrier'], router.reactions[i]['summary'], router.reactions[i]['n_competing'])  
        for i in router.reactions if 'Li2CO3' in router.reactions[i]['summary']])
# Out:
# [(0.04636226707152522,
#   '2.5 LiTi2O4(mp-5670) + 0.75 Li2CO3(mp-3054) + -0.75 CO2(mp-20066) + 0.625 O2(mp-12957)',
#   13),
#  (0.15955761043511124,
#   '2.0 Li2CO3(mp-3054) + -2.0 CO2(mp-20066) + 2.5 Ti2O3(mp-458) + 1.25 O2(mp-12957)',
#   12),
#  (0.16708339057171437,
#   '2.0 Li2CO3(mp-3054) + 1.6667 Ti3O5(mp-1147) + -2.0 CO2(mp-20066) + 0.8333 O2(mp-12957)',
#   29),
#  (0.18356650075302533,
#   '2.0 Li2CO3(mp-3054) + 5.0 TiO2(mp-554278) + -2.0 CO2(mp-20066)',
#   35),
#  (0.23041390806568857,
#   '0.3333 Li2CO3(mp-3054) + 1.6667 Ti3O5(mp-1147) + -0.3333 CO2(mp-20066) + 1.6667 Li2O2(mp-841)',
#   57),
#  (0.30189292575207416,
#   '2.0 Li2CO3(mp-3054) + -7.0 CO2(mp-20066) + 10.0 O2(mp-12957) + 5.0 TiC(mp-631)',
#   104),
#  (0.3027391332552641,
#   '0.625 Ti8C5(mp-27919) + 2.0 Li2CO3(mp-3054) + -5.125 CO2(mp-20066) + 8.125 O2(mp-12957)',
#   104),
#  (0.3030967343259041,
#   '2.0 Li2CO3(mp-3054) + 2.5 Ti2C(mp-10721) + -4.5 CO2(mp-20066) + 7.5 O2(mp-12957)',
#   104),
#  (0.32182929365525026,
#   '2.0 Li2CO3(mp-3054) + 5.0 Ti(mp-72) + -2.0 CO2(mp-20066) + 5.0 O2(mp-12957)',
#   104),
#  (0.3256322759634003,
#   '2.0 Li2CO3(mp-3054) + 0.8333 Ti6O(mp-554098) + -2.0 CO2(mp-20066) + 4.5833 O2(mp-12957)',
#   104),
#  (0.32826608249821415,
#   '2.0 Li2CO3(mp-3054) + 2.5 Ti2O(mp-1215) + -2.0 CO2(mp-20066) + 3.75 O2(mp-12957)',
#   104),
#  (0.33004481072448694,
#   '2.0 Li2CO3(mp-3054) + 1.6667 Ti3O(mp-2591) + -2.0 CO2(mp-20066) + 4.1667 O2(mp-12957)',
#   104),
#  (0.33315648313774954,
#   '2.0 Li2CO3(mp-3054) + -2.0 CO2(mp-20066) + 5.0 TiO(mp-1071163) + 2.5 O2(mp-12957)',
#   104)]
