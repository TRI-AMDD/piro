# %%
mp_id = 'mp-5020'

# %%
from rxn.route import SynthesisRoutes

# %%
router = SynthesisRoutes(mp_id, add_element='C')

# %%
router.recommend_routes(t=1500, p=0.000394737, allow_gas_release=True)
# Out:
# <div>
#
#
#             <div id="9c707fe1-20e1-4627-8e23-a705c4698394" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c707fe1-20e1-4627-8e23-a705c4698394")) {
#                     Plotly.newPlot(
#                         '9c707fe1-20e1-4627-8e23-a705c4698394',
# ...

# %%
import numpy as np

# %%
sorted([(router.reactions[i]['barrier'], router.reactions[i]['summary'], router.reactions[i]['n_competing'])  
        for i in router.reactions if 'BaCO3' in router.reactions[i]['summary']])
# Out:
# [(0.11235806975955384,
#   '0.1667 Ba2Ti6O13(mp-7733) + -0.6667 CO2(mp-20066) + 0.6667 BaCO3(mp-5504) + 0.0833 O2(mp-12957)',
#   22),
#  (0.11521413859273322,
#   '0.1667 BaO2(mp-1105) + 0.1667 Ba2Ti6O13(mp-7733) + -0.5 CO2(mp-20066) + 0.5 BaCO3(mp-5504)',
#   13),
#  (0.12180655326919636,
#   '0.5 Ti2O3(mp-458) + -1.0 CO2(mp-20066) + 1.0 BaCO3(mp-5504) + 0.25 O2(mp-12957)',
#   6),
#  (0.1313100812140098,
#   '0.3333 BaO2(mp-1105) + -0.6667 CO2(mp-20066) + 0.6667 BaCO3(mp-5504) + 0.3333 Ti3O5(mp-1147)',
#   10),
#  (0.13275926457824996,
#   '0.5 BaO2(mp-1105) + 0.5 Ti2O3(mp-458) + -0.5 CO2(mp-20066) + 0.5 BaCO3(mp-5504)',
#   3),
#  (0.15037378999490073,
#   '0.4615 BaO2(mp-1105) + -0.3846 CO2(mp-20066) + 0.3846 BaCO3(mp-5504) + 0.0769 Ba2Ti13O22(mp-28917)',
#   15),
#  (0.15079889403177826,
#   '-0.6923 CO2(mp-20066) + 0.6923 BaCO3(mp-5504) + 0.0769 Ba4Ti13O30(mp-29298)',
#   19),
#  (0.17233211368590826,
# ...
