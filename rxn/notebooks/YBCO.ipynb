# %%
mp_id = 'mp-20674'

# %%
from rxn.route import SynthesisRoutes

# %%
router = SynthesisRoutes(mp_id, add_element='C')
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:  2.4min finished
# Epitaxies ready
# Similarity matrix ready
# Precursor library ready.

# %%
router.simple_precursors
# Out:
# False

# %%
router.recommend_routes(temperature=1500, pressure=0.000394737, allow_gas_release=True, max_component_precursors=2)
# Out:
# <div>
#
#
#             <div id="5feddd2f-229a-459c-8f58-a685e1715d7f" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5feddd2f-229a-459c-8f58-a685e1715d7f")) {
#                     Plotly.newPlot(
#                         '5feddd2f-229a-459c-8f58-a685e1715d7f',
# ...

# %%
print(router.plot_data['summary'].values)

# %%
import numpy as np

# %%
sorted([(router.reactions[i]['barrier'], router.reactions[i]['summary'], router.reactions[i]['n_competing'])  
        for i in router.reactions if 'BaCO3' in router.reactions[i]['summary']])

# %%
[i.composition.reduced_formula for i in router.precursor_library]

# %%
router.elts
